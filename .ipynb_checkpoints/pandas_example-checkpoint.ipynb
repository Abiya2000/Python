# %%
import pandas as pd

# %%
import pymysql as mq

# %%
import sqlalchemy as sqla
engine = sqla.create_engine("mysql+pymysql://root:Akab%401718@localhost:3306/main")
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/main)

# %%
query = "show tables"
queryres = pd.read_sql_query(query, engine)
queryres
# Out:
#   Tables_in_main
# 0      employees
# 1        table_1
# 2        table_2

# %%
table_1 = pd.read_sql_table("table_1", engine)
table_1
# Out:
#    s_no    name  gender  salary
# 0     1   Abhay    Male   26000
# 1     2   Aruno    Male   30000
# 2     3   Disha  Female   27000
# 3     4   Pooja  Female   24000
# 4     5    Jack    Male   32000
# 5     6  Aparna  Female   40000
# 6     7  Aadhya  Female   15000
# 7     8  Varsha  Female   20000
# 8     9    Ajay    Male   50000
# 9    10  Raashi  Female  100000

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Akhilesh_Abhay\\Desktop\\pythonproj'

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints', 'movierecommend.ipynb', 'pandas_example.ipynb']

# %%
query2 = pd.read_sql_table("datajobs", engine)

# %%
query2
# Out:
#      Position                                          Job Title  \
# 0           1                                     Data Scientist
# 1           2  Senior Artificial Intelligence Researcher for ...
# 2           3                              Senior Data Scientist
# 3           4                                     Data Scientist
# 4           5                                     Data Scientist
# ..        ...                                                ...
# 195       196                        Sr. Manager, Data Scientist
# 196       197                   Senior Data Scientist (New York)
# 197       198                            Contract Data Scientist
# 198       199                      Statistical Programmer ONSITE
# 199       200                                     Data Scientist
#
#                                             Company  \
# 0                                       Robert Half
# 1    Johns Hopkins Applied Physics Laboratory (APL)
# ...

# %%
query3 = "create table table_2 as select * from table_1"

# %%
query3res = pd.read_sql_query(query3,engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 query3res = pd.read_sql_query(query3,engine)
#
# File ~\Python\Python312\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# ...

# %%
query4 = "select * from table_1 A join table_2 B on A.s_no = B.s_no"
query4res = pd.read_sql_query(query4,engine)

# %%
query4res
# Out:
#    s_no    name  gender  salary  s_no    name  gender  salary
# 0     1   Abhay    Male   26000     1   Abhay    Male   26000
# 1     2   Aruno    Male   30000     2   Aruno    Male   30000
# 2     3   Disha  Female   27000     3   Disha  Female   27000
# 3     4   Pooja  Female   24000     4   Pooja  Female   24000
# 4     5    Jack    Male   32000     5    Jack    Male   32000
# 5     6  Aparna  Female   40000     6  Aparna  Female   40000
# 6     7  Aadhya  Female   15000     7  Aadhya  Female   15000
# 7     8  Varsha  Female   20000     8  Varsha  Female   20000
# 8     9    Ajay    Male   50000     9    Ajay    Male   50000
# 9    10  Raashi  Female  100000    10  Raashi  Female  100000
