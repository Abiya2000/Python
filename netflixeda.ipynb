# %%
import pandas as pd
import sqlalchemy as sqla
import pymysql as mq
engine = sqla.create_engine("mysql+pymysql://root:Akab%401718@localhost/main")

# %%
query = "show tables"
queryres = pd.read_sql_query(query, engine)
queryres
# Out:
#   Tables_in_main
# 0      employees
# 1   netflix_data
# 2        table_1
# 3        table_2

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Akhilesh_Abhay\\Desktop\\pythonproj'

# %%
os.chdir("C:\\Users\\Akhilesh_Abhay\\Documents\\bigquerykeyfile\\archive (1)")

# %%
os.listdir('.')
# Out:
# ['netflix_titles.csv', 'netflix_titles.xlsx']

# %%
df1 = pd.read_csv('netflix_titles.csv')
df1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df1.shape
# Out:
# (8807, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df1.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df1.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df1.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df1['director'] = df1['director'].fillna("Director Missing")

# %%
df1['cast'] = df1['cast'].fillna("Director Missing")

# %%
df1=df1.dropna()

# %%
df1.shape
# Out:
# (7961, 12)

# %%
df1
# Out:
#      show_id     type                          title          director  \
# 0         s1    Movie           Dick Johnson Is Dead   Kirsten Johnson
# 1         s2  TV Show                  Blood & Water  Director Missing
# 4         s5  TV Show                   Kota Factory  Director Missing
# 7         s8    Movie                        Sankofa      Haile Gerima
# 8         s9  TV Show  The Great British Baking Show   Andy Devonshire
# ...      ...      ...                            ...               ...
# 8801   s8802    Movie                        Zinzana   Majid Al Ansari
# 8802   s8803    Movie                         Zodiac     David Fincher
# 8804   s8805    Movie                     Zombieland   Ruben Fleischer
# 8805   s8806    Movie                           Zoom      Peter Hewitt
# 8806   s8807    Movie                         Zubaan       Mozez Singh
#
#                                                    cast  \
# 0                                      Director Missing
# ...

# %%
df1.to_sql(name = "netflix_data",con=engine, if_exists='replace', index=False)
# Out:
# 7961

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1['release_year'].plot(kind='hist')
plt.show()

# %%
df1['country'].plot(kind='hist')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df1['country'].plot(kind='hist')
#       2 plt.show()
#
# File ~\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
# ...

# %% [markdown]
# df1['show_id','listed_in']

# %%
df2 = df1[['show_id','listed_in']]

# %%
df2
# Out:
#      show_id                                          listed_in
# 0         s1                                      Documentaries
# 1         s2    International TV Shows, TV Dramas, TV Mysteries
# 4         s5  International TV Shows, Romantic TV Shows, TV ...
# 7         s8   Dramas, Independent Movies, International Movies
# 8         s9                       British TV Shows, Reality TV
# ...      ...                                                ...
# 8801   s8802            Dramas, International Movies, Thrillers
# 8802   s8803                     Cult Movies, Dramas, Thrillers
# 8804   s8805                            Comedies, Horror Movies
# 8805   s8806                 Children & Family Movies, Comedies
# 8806   s8807     Dramas, International Movies, Music & Musicals
#
# [7961 rows x 2 columns]

# %%
df2[['listed_in1','listed_in2','listed_in3']]=df2['listed_in'].str.split(',',expand=True)
# Out:
# C:\Users\Akhilesh_Abhay\AppData\Local\Temp\ipykernel_9820\4213294961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['listed_in1','listed_in2','listed_in3']]=df2['listed_in'].str.split(',',expand=True)
# C:\Users\Akhilesh_Abhay\AppData\Local\Temp\ipykernel_9820\4213294961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['listed_in1','listed_in2','listed_in3']]=df2['listed_in'].str.split(',',expand=True)
# ...

# %%
df2
# Out:
#      show_id                                          listed_in  \
# 0         s1                                      Documentaries
# 1         s2    International TV Shows, TV Dramas, TV Mysteries
# 4         s5  International TV Shows, Romantic TV Shows, TV ...
# 7         s8   Dramas, Independent Movies, International Movies
# 8         s9                       British TV Shows, Reality TV
# ...      ...                                                ...
# 8801   s8802            Dramas, International Movies, Thrillers
# 8802   s8803                     Cult Movies, Dramas, Thrillers
# 8804   s8805                            Comedies, Horror Movies
# 8805   s8806                 Children & Family Movies, Comedies
# 8806   s8807     Dramas, International Movies, Music & Musicals
#
#                     listed_in1             listed_in2             listed_in3
# 0                Documentaries                   None                   None
# ...

# %%
df2=df2.drop("listed_in", axis='columns')

# %%
df2
# Out:
#      show_id                listed_in1             listed_in2  \
# 0         s1             Documentaries                   None
# 1         s2    International TV Shows              TV Dramas
# 4         s5    International TV Shows      Romantic TV Shows
# 7         s8                    Dramas     Independent Movies
# 8         s9          British TV Shows             Reality TV
# ...      ...                       ...                    ...
# 8801   s8802                    Dramas   International Movies
# 8802   s8803               Cult Movies                 Dramas
# 8804   s8805                  Comedies          Horror Movies
# 8805   s8806  Children & Family Movies               Comedies
# 8806   s8807                    Dramas   International Movies
#
#                  listed_in3
# 0                      None
# 1              TV Mysteries
# 4               TV Comedies
# 7      International Movies
# 8                      None
# ...                     ...
# ...

# %%
mdf2 = pd.melt(frame=df2, id_vars=['show_id'],value_vars=['listed_in1','listed_in2','listed_in3'], var_name='category', value_name='type')

# %%
mdf2
# Out:
#       show_id    category                    type
# 0          s1  listed_in1           Documentaries
# 1          s2  listed_in1  International TV Shows
# 2          s5  listed_in1  International TV Shows
# 3          s8  listed_in1                  Dramas
# 4          s9  listed_in1        British TV Shows
# ...       ...         ...                     ...
# 23878   s8802  listed_in3               Thrillers
# 23879   s8803  listed_in3               Thrillers
# 23880   s8805  listed_in3                    None
# 23881   s8806  listed_in3                    None
# 23882   s8807  listed_in3        Music & Musicals
#
# [23883 rows x 3 columns]

# %%
docus = mdf2[mdf2["type"] == 'Documentaries']

# %%
docus
# Out:
#      show_id    category           type
# 0         s1  listed_in1  Documentaries
# 52       s92  listed_in1  Documentaries
# 56       s97  listed_in1  Documentaries
# 60      s102  listed_in1  Documentaries
# 71      s118  listed_in1  Documentaries
# ...      ...         ...            ...
# 7897   s8740  listed_in1  Documentaries
# 7902   s8745  listed_in1  Documentaries
# 7904   s8747  listed_in1  Documentaries
# 7914   s8757  listed_in1  Documentaries
# 7920   s8764  listed_in1  Documentaries
#
# [759 rows x 3 columns]

# %%
docushows = mdf2.loc[mdf2["type"] == 'Documentaries', "show_id"]

# %%
docushows
# Out:
# 0          s1
# 52        s92
# 56        s97
# 60       s102
# 71       s118
#         ...
# 7897    s8740
# 7902    s8745
# 7904    s8747
# 7914    s8757
# 7920    s8764
# Name: show_id, Length: 759, dtype: object

# %%
res1 = mdf2.loc[0,:]

# %%
res1
# Out:
# show_id                s1
# category       listed_in1
# type        Documentaries
# Name: 0, dtype: object

# %%
nparrmdf2 = mdf2.to_numpy()

# %%
nparrmdf2
# Out:
# array([['s1', 'listed_in1', 'Documentaries'],
#        ['s2', 'listed_in1', 'International TV Shows'],
#        ['s5', 'listed_in1', 'International TV Shows'],
#        ...,
#        ['s8805', 'listed_in3', None],
#        ['s8806', 'listed_in3', None],
#        ['s8807', 'listed_in3', ' Music & Musicals']], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 import git
#
# ModuleNotFoundError: No module named 'git'
